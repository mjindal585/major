# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot

import re
import sklearn

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv('finalized.csv')
df.head()
# Out:
#       ID  Gender  Years_in_US  Maritial_Status  People_Family  \
# 0  73557    Male            0                1              3
# 1  73558    Male            0                1              4
# 2  73559    Male            0                1              2
# 3  73560    Male            0                0              4
# 4  73561  Female            0                1              2
#
#    People_Household  Family_income  Household_Income  GlycoHemoglobin  \
# 0                 3            NaN               4.0             13.9
# 1                 4            NaN               7.0              9.1
# 2                 2            NaN              10.0              8.9
# 3                 4            NaN               9.0              5.4
# 4                 2            NaN              15.0              4.9
#
#    ArmCircum  SaggitalAbdominal  GripStrength  Breast_fed  Taking_Insulin  \
# 0       35.3               20.6          55.2           1               1
# ...

# %%
show = sns.pairplot(df.drop(['ID','Gender','Years_in_US','Maritial_Status','Diabetes','Taking_Insulin','Taking_Oral_Agents', 'GlycoHemoglobin'], axis=1), hue='Diabetes', size=1.5, diag_kind='kde')

show.set(xticklabels=[])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Diabetes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-812ce0cac82d> in <module>
# ...
