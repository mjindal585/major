# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('concat.csv')

# %%
df.head()
# Out:
#     SEQN  URXUMA  URXUMS  URXUCR.x   URXCRS  URDACT     WTSAF2YR.x  LBXAPB  \
# 0  73557     4.3     4.3      39.0   3447.6   11.03            NaN     NaN
# 1  73558   153.0   153.0      50.0   4420.0  306.00            NaN     NaN
# 2  73559    11.9    11.9     113.0   9989.2   10.53  142196.890197    57.0
# 3  73560    16.0    16.0      76.0   6718.4   21.05            NaN     NaN
# 4  73561   255.0   255.0     147.0  12994.8  173.47  142266.006548    92.0
#
#    LBDAPBSI  LBXSAL  ...  WHD080U  WHD080L  WHD110  WHD120  WHD130  WHD140  \
# 0       NaN     4.1  ...      NaN     40.0   270.0   200.0    69.0   270.0
# 1       NaN     4.7  ...      NaN      NaN   240.0   250.0    72.0   250.0
# 2      0.57     3.7  ...      NaN      NaN   180.0   190.0    70.0   228.0
# 3       NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN     NaN
# 4      0.92     4.3  ...      NaN      NaN   150.0   135.0    67.0   170.0
#
#    WHQ150  WHQ030M  WHQ500  WHQ520
# ...

# %%
df.dropna(axis=1, how='all')
df.dropna(axis=0, how='all')

df = df.rename(columns = {'SEQN' : 'ID',
                          'RIAGENDR' : 'Gender',
                          'DMDYRSUS' : 'Years_In_US',
                          'DMDMARTL':'Maritial_Status',
                          'DMDFMSIZ':'People_Family',
                          'DMDHHSIZ':'People_Household',
                          'INDFMPIR' : 'Family_Income',
                          'INDHHIN2':'Household_Income',
                          'LBXGH' : 'GlycoHemoglobin',
                          'BMXARMC' : 'ArmCircum',
                          'BMDAVSAD' : 'SaggitalAbdominal',
                          'MGDCGSZ' : 'GripStrength',
                          'DRABF' : 'Breast_Fed',
                          'DIQ050':'Taking_Insulin',
                          'DIQ070':'Taking_Oral_Agents',
                          'DIQ080':'Eyes_Affected',
                         'DIQ300S':'Recent_BP'})

df = df.loc[:, ['ID', 'Gender', 'Years_in_US','Maritial_Status','People_Family','People_Household','Family_income','Household_Income',
                'GlycoHemoglobin', 'ArmCircum','SaggitalAbdominal', 'GripStrength', 'Breast_fed','Taking_Insulin',
               'Taking_Oral_Agents','Eyes_Affected','Recent_BP']]

df.describe()
# Out:
#                  ID       Gender  Years_in_US  Maritial_Status  People_Family  \
# count   9813.000000  9813.000000          0.0       5561.00000    9813.000000
# mean   78644.559971     1.509426          NaN          2.57130       3.730052
# std     2938.592266     0.499937          NaN          2.65193       1.774712
# min    73557.000000     1.000000          NaN          1.00000       1.000000
# 25%    76092.000000     1.000000          NaN          1.00000       2.000000
# 50%    78643.000000     2.000000          NaN          1.00000       4.000000
# 75%    81191.000000     2.000000          NaN          5.00000       5.000000
# max    83731.000000     2.000000          NaN         99.00000       7.000000
#
#        People_Household  Family_income  Household_Income  GlycoHemoglobin  \
# count       9813.000000            0.0       9683.000000      6643.000000
# mean           3.874147            NaN         10.868016         5.642556
# ...

# %%
df.to_csv('renamed.csv',index=False)
