# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('finalized.csv')
df2 = pd.read_csv('adult.csv')

# %%
df = pd.concat([df1, df2], axis=1, join='inner')

# %%
df.head()
# Out:
#       ID  Gender  Years_in_US  Maritial_Status  People_Family  \
# 0  73557    Male            0                1              3
# 1  73558    Male            0                1              4
# 2  73559    Male            0                1              2
# 3  73560    Male            0                0              4
# 4  73561  Female            0                1              2
#
#    People_Household  Family_income  Household_Income  GlycoHemoglobin  \
# 0                 3            NaN               4.0             13.9
# 1                 4            NaN               7.0              9.1
# 2                 2            NaN              10.0              8.9
# 3                 4            NaN               9.0              5.4
# 4                 2            NaN              15.0              4.9
#
#    ArmCircum  ...      marital-status         occupation  relationship   race  \
# 0       35.3  ...       Never-married  Machine-op-inspct     Own-child  Black
# ...

# %%
df.nunique()
# Out:
# ID                    9813
# Gender                   2
# Years_in_US              1
# Maritial_Status          2
# People_Family            7
# People_Household         7
# Family_income            0
# Household_Income        16
# GlycoHemoglobin        100
# ArmCircum              408
# SaggitalAbdominal      271
# GripStrength          1128
# Breast_fed               1
# Taking_Insulin           2
# Taking_Oral_Agents       2
# Eyes_Affected            2
# Recent_BP               73
# Diabetes                 3
# age                     71
# workclass                9
# fnlwgt                8381
# education               16
# educational-num         16
# marital-status           7
# occupation              15
# relationship             6
# race                     5
# gender                   2
# capital-gain           104
# capital-loss            76
# hours-per-week          87
# native-country          41
# income                   2
# dtype: int64

# %%
df = df.drop(['Years_in_US','Breast_fed','Maritial_Status','Family_income','Household_Income','People_Household','fnlwgt','Maritial_Status','capital-gain','capital-loss','hours-per-week'],axis=1)

# %%
df.head()
# Out:
#       ID  Gender  People_Family  GlycoHemoglobin  ArmCircum  \
# 0  73557    Male              3             13.9       35.3
# 1  73558    Male              4              9.1       34.7
# 2  73559    Male              2              8.9       33.5
# 3  73560    Male              4              5.4       21.0
# 4  73561  Female              2              4.9       25.2
#
#    SaggitalAbdominal  GripStrength  Taking_Insulin  Taking_Oral_Agents  \
# 0               20.6          55.2               1                   1
# 1               24.4          61.5               1                   1
# 2               25.6          91.0               1                   1
# 3               14.9          32.2               1                   0
# 4               20.7          30.9               1                   0
#
#    Eyes_Affected  ...  workclass     education  educational-num  \
# 0              1  ...    Private          11th                7
# ...

# %%
df.nunique()
# Out:
# ID                    9813
# Gender                   2
# People_Family            7
# GlycoHemoglobin        100
# ArmCircum              408
# SaggitalAbdominal      271
# GripStrength          1128
# Taking_Insulin           2
# Taking_Oral_Agents       2
# Eyes_Affected            2
# Recent_BP               73
# Diabetes                 3
# age                     71
# workclass                9
# education               16
# educational-num         16
# marital-status           7
# occupation              15
# relationship             6
# race                     5
# gender                   2
# native-country          41
# income                   2
# dtype: int64

# %%
df
# Out:
#          ID  Gender  People_Family  GlycoHemoglobin  ArmCircum  \
# 0     73557    Male              3             13.9       35.3
# 1     73558    Male              4              9.1       34.7
# 2     73559    Male              2              8.9       33.5
# 3     73560    Male              4              5.4       21.0
# 4     73561  Female              2              4.9       25.2
# ...     ...     ...            ...              ...        ...
# 9808  83727  Female              7              5.0       29.9
# 9809  83728    Male              6              5.4       14.7
# 9810  83729    Male              2              5.3       37.0
# 9811  83730  Female              4              5.4       19.0
# 9812  83731  Female              3              5.4       25.0
#
#       SaggitalAbdominal  GripStrength  Taking_Insulin  Taking_Oral_Agents  \
# 0                  20.6          55.2               1                   1
# ...

# %%
df = df.drop(['Gender','relationship','educational-num'],axis=1)

# %%
df
# Out:
#          ID  People_Family  GlycoHemoglobin  ArmCircum  SaggitalAbdominal  \
# 0     73557              3             13.9       35.3               20.6
# 1     73558              4              9.1       34.7               24.4
# 2     73559              2              8.9       33.5               25.6
# 3     73560              4              5.4       21.0               14.9
# 4     73561              2              4.9       25.2               20.7
# ...     ...            ...              ...        ...                ...
# 9808  83727              7              5.0       29.9               19.1
# 9809  83728              6              5.4       14.7               20.7
# 9810  83729              2              5.3       37.0               24.3
# 9811  83730              4              5.4       19.0               20.7
# 9812  83731              3              5.4       25.0               17.5
#
#       GripStrength  Taking_Insulin  Taking_Oral_Agents  Eyes_Affected  \
# ...

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['ID',
#  'People_Family',
#  'GlycoHemoglobin',
#  'ArmCircum',
#  'SaggitalAbdominal',
#  'GripStrength',
#  'Taking_Insulin',
#  'Taking_Oral_Agents',
#  'Eyes_Affected',
#  'Recent_BP',
#  'Diabetes',
#  'age',
#  'workclass',
#  'education',
#  'educational-num',
#  'marital-status',
#  'occupation',
#  'race',
#  'gender',
#  'native-country',
#  'income']

# %%
'''rearrangecols = ['ID',
                 'age','gender','maritial-status','occupation',
 'People_Family',
 'GlycoHemoglobin',
 'ArmCircum',
 'SaggitalAbdominal',
 'GripStrength',
 'Taking_Insulin',
 'Taking_Oral_Agents',
 'Eyes_Affected',
 'Recent_BP',
 'Diabetes',
 'workclass',
 'education',
 'educational-num',
  'race',
 'native-country',
 'income']'''
